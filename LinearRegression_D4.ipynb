# %%
import pandas as pd

# %%
df = pd.read_csv("houses.csv")

# %%
df
# Out:
#     Size (sq ft)  Bedrooms  Price ($)
# 0           2844         4     379360
# 1           2994         5     449420
# 2           1524         4     267640
# 3            972         5     198020
# 4           3491         3     406140
# 5           1894         4     304140
# 6           1184         2     177240
# 7           3639         1     384290
# 8           3023         2     357800
# 9           1744         3     261260
# 10          2766         4     376780
# 11          2745         2     330580
# 12          3125         3     403550
# 13          2593         2     315570
# 14          1810         1     215790
# 15          1670         2     234540
# 16          3373         1     364930
# 17          3625         4     425190
# 18          3783         3     440430
# 19          2744         2     331240
# 20          1912         3     281580
# 21          3117         3     403070
# 22          2893         5     438690
# 23          1363         1     165630
# ...

# %%
#show number of rows and coloume in dataset in form of tuple
df.shape
# Out:
# (50, 3)

# %%
#provide a proper summery of a dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Size (sq ft)  50 non-null     int64
#  1   Bedrooms      50 non-null     int64
#  2   Price ($)     50 non-null     int64
# dtypes: int64(3)
# memory usage: 1.3 KB

# %%
#checks for missing values in the dataset
df.isnull().sum()
# Out:
# Size (sq ft)    0
# Bedrooms        0
# Price ($)       0
# dtype: int64

# %%
#genreate staticstical data from a dataset  
df.describe()
# Out:
#        Size (sq ft)   Bedrooms      Price ($)
# count     50.000000  50.000000      50.000000
# mean    2359.780000   2.980000  317071.800000
# std      812.260748   1.203566   87714.475958
# min      972.000000   1.000000  165630.000000
# 25%     1727.500000   2.000000  238007.500000
# 50%     2294.000000   3.000000  323955.000000
# 75%     3015.750000   4.000000  394167.500000
# max     3784.000000   5.000000  451750.000000

# %%
from sklearn.linear_model import LinearRegression

# %%
x= df[["Size (sq ft)" , "Bedrooms" ]]

# %%
x.head()
# Out:
#    Size (sq ft)  Bedrooms
# 0          2844         4
# 1          2994         5
# 2          1524         4
# 3           972         5
# 4          3491         3

# %%
y = df["Price ($)"]

# %%
y.head()
# Out:
# 0    379360
# 1    449420
# 2    267640
# 3    198020
# 4    406140
# Name: Price ($), dtype: int64

# %%
x.shape
# Out:
# (50, 2)

# %%
y.shape
# Out:
# (50,)

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 21710.604649571178

# %%
model.coef_
# Out:
# array([   94.32147613, 24423.91356246])

# %%
Size= float(input("enter the size of the house in sq"))
bed = int(input("enter no of bed room"))
model.predict([[Size,bed]])
# Out:
# enter the size of the house in sq 100
# enter no of bed room 5
# C:\Users\vivek\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([153262.32007453])

# %%
import joblib

# %%
joblib.dump(model,"house_predictor.pkl")
# Out:
# ['house_predictor.pkl']
